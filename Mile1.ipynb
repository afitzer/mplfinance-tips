# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import mplfinance as mpf
from matplotlib import style

# %%
# %matplotlib inline

# %%
plt.style.use(style['base_mpl_style'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 plt.style.use(style['base_mpl_style'])
#
# TypeError: 'module' object is not subscriptable

# %%
data = yf.download('AAPL', start='2021-01-01', end='2022-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
intraday = yf.download('AAPL', period = '5d', interval='1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mpf.plot(data)
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])

# %%
mpf.plot(data, type='candle', title='Apple Stock')
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])

# %%
mpf.plot(data, type='line', title='Apple Stock')
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])

# %%
mpf.plot(data, type='renko', title='Apple Stock')
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])

# %%
mpf.plot(data, type='pnf', title='Apple Stock')
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])

# %%
mpf.plot(data, type="ohlc", mav=15, title='Apple Stock')
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])

# %%
mpf.plot(data, type="candle", mav=(7, 14, 21), title='Apple Stock')
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])

# %%
mpf.plot(data, type="candle", mav=(7, 14, 21), volume=True, title='Apple Stock')
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])

# %%
mpf.plot(data, type="candle", mav=(7, 14, 21), volume=True, show_nontrading=True, title='Apple Stock')
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])

# %%
iday = intraday.loc["2022-10-25 15:00":"2022-10-25 16:00", :]
mpf.plot(iday, type="candle", mav=(7, 12))
# Out:
# c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_styles.py:24: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style['base_mpl_style'])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [17], line 2
#       1 iday = intraday.loc["2022-10-25 15:00":"2022-10-25 16:00", :]
# ----> 2 mpf.plot(iday, type="candle", mav=(7, 12))
#
# File c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\plotting.py:486, in plot(data, **kwargs)
#     483     else:
#     484         volumeAxes = None
# --> 486 fmtstring = _determine_format_string(dates, config['datetime_format'])
#     488 ptype = config['type']
#     490 if config['show_nontrading']:
#
# File c:\Users\alexp\Documents\mplfinance-tips\env\lib\site-packages\mplfinance\_helpers.py:47, in _determine_format_string(dates, datetime_format)
#      41 def _determine_format_string( dates, datetime_format=None ):
#      42     """
#      43     Determine the datetime format string based on the averge number
#      44     of days between data points, or if the user passed in kwarg
#      45     datetime_format, use that as an override.
#      46     """
# ---> 47     avg_days_between_points = (dates[-1] - dates[0]) / float(len(dates))
#      49     if datetime_format is not None:
#      50         return datetime_format
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
print('complete')
# Out:
# complete
